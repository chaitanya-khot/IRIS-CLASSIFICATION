# %% [markdown]
# <a href="https://colab.research.google.com/github/thisiskhot/IRIS-CLASSIFICATION/blob/main/data_cleaning_challenge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_csv("data_cleaning_challenge.csv")
data
# Out:
#                  Row Type       Iter Number             Power1  Speed1  \
# 0      first name: Person  last name: Human  date: end of time     NaN
# 1                     NaN               NaN                NaN     NaN
# 2                Row Type       Iter Number             Power1  Speed1
# 3                    Iter                 1                360     108
# 4                    Iter                 2                684     508
# ...                   ...               ...                ...     ...
# 76372                Iter                 6                879      73
# 76373             Average               979                641     531
# 76374             Maximum               783                172     941
# 76375            Std.Dev.               221                112     717
# 76376               Total               429                  -       -
#
#        Speed2  Electricity  Effort  Weight  Torque  Unnamed: 9 Unnamed: 10
# ...

# %%
drop
